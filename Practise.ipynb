# %%
# %matplotlib inline

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

plt.style.use('ggplot')

pd.__version__
# Out:
# u'0.17.0'

# %%
fuel_subsidies = pd.read_csv("SSF_fuel_subsidies.csv")
SSF_subsidies = pd.read_csv("SSF_subsidies.csv")

# %%
SSF_subsidies_all = pd.merge(left=SSF_subsidies, right=fuel_subsidies, how='left')

# %%
SSF_subsidies_all
# Out:
#        ID  Cnumber  RegionID RegionName Type                    SubType  \
# 0    1418      608         2       Asia   A1           Fisheries mangt.
# 1    1419      608         2       Asia   A2                Fishery R&D
# 2    1420      608         2       Asia   A3                       MPAs
# 3    1421      608         2       Asia   B1  Boat constsruct. & renov.
# 4    1422      608         2       Asia   B2    Fisheries dev. projects
# 5    1423      608         2       Asia   B3      Fishing port develop.
# 6    1424      608         2       Asia   B4  Markt. & storage infrast.
# 7    1425      608         2       Asia   B5              Tax exemption
# 8    1426      608         2       Asia   B6             Fishing access
# 9    1427      608         2       Asia   B7             Fuel subsidies
# 10   1428      608         2       Asia   C1          Fisher assistance
# 11   1429      608         2       Asia   C2             Vessel buyback
# ...
