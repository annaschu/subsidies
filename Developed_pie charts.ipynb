# %%
import pandas as pd

import matplotlib.pyplot as plt

import matplotlib as mpl

import numpy as np

# %matplotlib inline

plt.style.use('ggplot')

pd.set_option('precision',3)

from IPython.display import display, HTML

pd.__version__
# Out:
# u'0.17.1'

# %%
Developed_pie = pd.read_csv('Developed_pie.csv')
Developed_pie
# Out:
#              Category  SSF Developed  SSF Developing  LSF Developed  \
# 0           Ambiguous         381812          238840        3339741
# 1          Beneficial        1717336          976087        5671980
# 2  Capacity-enhancing        1343190          947278       10612828
#
#    LSF Developing
# 0          225205
# 1         2709440
# 2         7207373

# %%
Developed_pie.plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#fbb52e','#00b3b3','#b30824'
    ],fontsize=32, figsize=(44, 10), explode = (0.01,0.01,0.01))

plt.savefig('Developed_pie.svg', dpi=1000, bbox_inches='tight')

# %%
Developed_pie['SSF Developed'].plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#fbb52e','#00b3b3','#b30824'
    ],fontsize=32, figsize=(20, 20), explode = (0.01,0.01,0.01))

plt.savefig('Developed_SSFpie.svg', dpi=1000, bbox_inches='tight')

# %%
Developed_pie['LSF Developed'].plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#fbb52e','#00b3b3','#b30824'
    ],fontsize=32, figsize=(20, 20), explode = (0.01,0.01,0.01))

plt.savefig('Developed_LSFpie.svg', dpi=1000, bbox_inches='tight')

# %%
Developed_pie['SSF Developing'].plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#fbb52e','#00b3b3','#b30824'
    ],fontsize=32, figsize=(20, 20), explode = (0.01,0.01,0.01))

plt.savefig('Developing_SSFpie.svg', dpi=1000, bbox_inches='tight')

# %%
Developed_pie['LSF Developing'].plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#fbb52e','#00b3b3','#b30824'
    ],fontsize=32, figsize=(20, 20), explode = (0.01,0.01,0.01))

plt.savefig('Developing_LSFpie.svg', dpi=1000, bbox_inches='tight')
