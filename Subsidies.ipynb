# %%
# %matplotlib inline

import pandas

import matplotlib.pyplot as plt

import numpy

pandas.__version__
# Out:
# u'0.17.0'

# %%
pandas.read_csv("Subsidiesnonfuel.csv")
# Out:
#        ID  Cnumber  RegionID RegionName Type                    SubType  \
# 0    1418      608         2       Asia   A1           Fisheries mangt.
# 1    1419      608         2       Asia   A2                Fishery R&D
# 2    1420      608         2       Asia   A3                       MPAs
# 3    1421      608         2       Asia   B1  Boat constsruct. & renov.
# 4    1422      608         2       Asia   B2    Fisheries dev. projects
# 5    1423      608         2       Asia   B3      Fishing port develop.
# 6    1424      608         2       Asia   B4  Markt. & storage infrast.
# 7    1425      608         2       Asia   B5              Tax exemption
# 8    1426      608         2       Asia   B6             Fishing access
# 9    1428      608         2       Asia   C1          Fisher assistance
# 10   1429      608         2       Asia   C2             Vessel buyback
# 11   1430      608         2       Asia   C3   Rural fisher communities
# ...

# %%
subdata = pandas.read_csv("Subsidiesnonfuel.csv")

subdata.head()
# Out:
#      ID  Cnumber  RegionID RegionName Type                    SubType  \
# 0  1418      608         2       Asia   A1           Fisheries mangt.
# 1  1419      608         2       Asia   A2                Fishery R&D
# 2  1420      608         2       Asia   A3                       MPAs
# 3  1421      608         2       Asia   B1  Boat constsruct. & renov.
# 4  1422      608         2       Asia   B2    Fisheries dev. projects
#
#   Category  ReEst_Subsidy2009 NewData   Developed  HDI_2005    Countries  \
# 0     Good      150317.400345   False  Developing     0.771  Philippines
# 1     Good      106929.633393   False  Developing     0.771  Philippines
# 2     Good       14325.450291   False  Developing     0.771  Philippines
# 3      Bad      291723.649784   False  Developing     0.771  Philippines
# 4      Bad        5987.405124    True  Developing     0.771  Philippines
#
#    %SSFsubsidies_assessed weighted_by_sectorsize  Data_group  \
# ...

# %%
subdata1 = subdata.loc[:,['RegionName', 'Countries', 'Type','ReEst_Subsidy2009','%SSFsubsidies_assessed', 'SSF_USD_1000','weighted_by_sectorsize', 'Data_group','%SSF_totalCatch_EEZ','%SSF_totalCatch_Country']]

# %%
subdata1
# Out:
#     RegionName    Countries Type  ReEst_Subsidy2009  %SSFsubsidies_assessed  \
# 0         Asia  Philippines   A1      150317.400345               28.662420
# 1         Asia  Philippines   A2      106929.633393               25.475502
# 2         Asia  Philippines   A3       14325.450291               28.662420
# 3         Asia  Philippines   B1      291723.649784               25.475502
# 4         Asia  Philippines   B2        5987.405124               25.475502
# 5         Asia  Philippines   B3           0.000000                     NaN
# 6         Asia  Philippines   B4        2305.468110               20.000000
# 7         Asia  Philippines   B5       92663.171127                0.000000
# 8         Asia  Philippines   B6           0.000000                     NaN
# 9         Asia  Philippines   C1       35605.265432              100.000000
# 10        Asia  Philippines   C2           0.000000                     NaN
# ...

# %%
subdata1.groupby('Countries').mean()
# Out:
#               ReEst_Subsidy2009  %SSFsubsidies_assessed   SSF_USD_1000  \
# Countries
# Angola             10237.880012               46.600420    6109.903975
# Argentina          15979.380763                6.634602     611.834535
# Australia          35837.897925               28.869204   11879.476657
# Brazil             45608.799719               41.769922   22155.662561
# Cameroon             990.648636               59.840000     863.139366
# Canada             91007.679915                4.643931    8063.195950
# Chile              11351.295369               35.358258    1709.074080
# China             210190.868001               17.032798   41477.915756
# Costa Rica          1073.009658               35.827459     845.831718
# Cuba                1346.602773               87.330906    4823.427914
# Denmark            12183.976386                6.700000    1449.474855
# Ecuador             4932.331802               14.998022    2178.627775
# ...

# %%
subdata.loc[:,['RegionName','Countries', 'Type' ,'ReEst_Subsidy2009','SSF_USD_1000']]
# Out:
#     RegionName    Countries Type  ReEst_Subsidy2009  SSF_USD_1000
# 0         Asia  Philippines   A1      150317.400345  43084.605195
# 1         Asia  Philippines   A2      106929.633393  27240.860867
# 2         Asia  Philippines   A3       14325.450291   4106.020784
# 3         Asia  Philippines   B1      291723.649784  74318.064163
# 4         Asia  Philippines   B2        5987.405124   1525.321511
# 5         Asia  Philippines   B3           0.000000           NaN
# 6         Asia  Philippines   B4        2305.468110    461.093622
# 7         Asia  Philippines   B5       92663.171127      0.000000
# 8         Asia  Philippines   B6           0.000000           NaN
# 9         Asia  Philippines   C1       35605.265432  35605.265432
# 10        Asia  Philippines   C2           0.000000           NaN
# 11        Asia  Philippines   C3       21737.044519  21737.044519
# 12        Asia        India   A1        6450.238140   2733.696798
# ...

# %%
subdata2 = subdata.loc[:,['RegionName','Countries','Type' ,'ReEst_Subsidy2009','SSF_USD_1000']]

# %%
subdata2.groupby(['RegionName','Countries']).sum()
# Out:
#                                                     ReEst_Subsidy2009  \
# RegionName                            Countries
# Africa                                Angola            122854.560149
#                                       Cameroon           11887.783631
#                                       Egypt              13528.962038
#                                       Gabon               7827.880786
#                                       Ghana              50868.989487
#                                       Guinea             36173.964783
#                                       Madagascar         11323.955852
#                                       Mauritania         26065.971094
#                                       Morocco           212774.245464
#                                       Mozambique         10422.289071
#                                       Namibia            51722.794987
#                                       Nigeria            47506.861375
# ...

# %%
subdata2.groupby(['RegionName','Type']).mean()
# Out:
#                                             ReEst_Subsidy2009  SSF_USD_1000
# RegionName                            Type
# Africa                                A1          8245.752386   1697.527432
#                                       A2          5435.445510   1713.785924
#                                       A3          1364.299050    251.218669
#                                       B1         11577.619251   6024.997530
#                                       B2          5975.584924   3312.711897
#                                       B3          2310.117047   4096.975804
#                                       B4          2807.220421   1522.243856
#                                       B5           858.139739    975.819315
#                                       B6           393.034828      0.000000
#                                       C1            76.322760    425.966415
#                                       C2             0.000000           NaN
# ...

# %%
subdata1.groupby(['RegionName','Countries']).mean()
# Out:
#                                                     ReEst_Subsidy2009  \
# RegionName                            Countries
# Africa                                Angola             10237.880012
#                                       Cameroon             990.648636
#                                       Egypt               1127.413503
#                                       Gabon                652.323399
#                                       Ghana               4624.453590
#                                       Guinea              3288.542253
#                                       Madagascar           943.662988
#                                       Mauritania          2172.164258
#                                       Morocco            17731.187122
#                                       Mozambique           868.524089
#                                       Namibia             4702.072272
#                                       Nigeria             4318.805580
# ...
