# %%
import pandas as pd

import matplotlib.pyplot as plt

import matplotlib as mpl

import numpy as np

# %matplotlib inline

plt.style.use('ggplot')

pd.set_option('precision',3)

from IPython.display import display, HTML

pd.__version__
# Out:
# u'0.17.1'

# %%
categories = pd.read_csv("subsidies_categories_pie.csv")
categories
# Out:
#              Category  LSF subsidies  SSF subsidies
# 0          Beneficial           8381           2694
# 1  Capacity-enhancing          17820           2290
# 2           Ambiguous           3565            621

# %%
categories['LSF subsidies'].plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#00b3b3','#b30824','#fbb52e'
    ],startangle=90, fontsize=32, figsize=(20, 20), explode = (0.01,0.01,0.01))

plt.savefig('Categories_pie_LSF.svg', dpi=1000, bbox_inches='tight')

# %%
categories['SSF subsidies'].plot(kind='pie',  subplots=True, legend=False, labels = None, colors = ['#00b3b3','#b30824','#fbb52e'
    ],startangle=90, fontsize=32, figsize=(20, 20), explode = (0.01,0.01,0.01))

plt.savefig('Categories_pie_SSF.svg', dpi=1000, bbox_inches='tight')
